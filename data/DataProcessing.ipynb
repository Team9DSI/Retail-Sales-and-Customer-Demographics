# %% [markdown]
# # Data Transformation and Preprocessing on Retail Sales Dataset
#
# This Jupyter notebook outlines the processes used to preprocess and transform the retail sales dataset. The transformations are designed to clean, enrich, and reorganize the data for subsequent analysis.
#
# The notebook covers essential preprocessing tasks, including handling missing values, enriching the data with random assignments, generating new features based on business logic, and structuring the data for analysis.
#
# ---

# %% [markdown]
# ### Overview of Key Points:
# - **Customer Demographics:** We create and merge `customer demographic data`, including assigning random `cities` and `provinces`.
# - **Seasonal Classification:** Transactions are categorized by `season` based on the date of the transaction.
# - **Customer Type:** Customers are labeled as `New` or `Returning` based on their transaction history.
# - **Data Enrichment:** Additional columns like `Total Spend`, `Product ID`, and `Season` are generated to provide more useful insights into the dataset.
# - **Data Saving:** The transformed data is saved into a new CSV file for future use.
#
# ---

# %% [markdown]
# ### 1. Load and Display Initial Dataset
#
# We begin by loading the retail sales dataset using `pandas.read_csv()`. The dataset is stored in the DataFrame `df` and displayed for inspection.

# %%
import pandas as pd
df = pd.read_csv('./raw/retail_sales_dataset.csv')
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# 1           2             500          1000
# 2           1              30            30
# 3           1             500           500
# 4           2              50           100
# ..        ...             ...           ...
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### 2. Create Customer Demographic Data
#
# The first 50 rows of the dataset are extracted to create a new DataFrame (`customers_df`) containing only `Customer ID`, `Gender`, and `Age` columns. This subset will be used for demographic enrichment.

# %%
customers_df = df.loc[:49,['Customer ID','Gender','Age']]
customers_df
# Out:
#    Customer ID  Gender  Age
# 0      CUST001    Male   34
# 1      CUST002  Female   26
# 2      CUST003    Male   50
# 3      CUST004    Male   37
# 4      CUST005    Male   30
# 5      CUST006  Female   45
# 6      CUST007    Male   46
# 7      CUST008    Male   30
# 8      CUST009    Male   63
# 9      CUST010  Female   52
# 10     CUST011    Male   23
# 11     CUST012    Male   35
# 12     CUST013    Male   22
# 13     CUST014    Male   64
# 14     CUST015  Female   42
# 15     CUST016    Male   19
# 16     CUST017  Female   27
# 17     CUST018  Female   47
# 18     CUST019  Female   62
# 19     CUST020    Male   22
# 20     CUST021  Female   50
# 21     CUST022    Male   18
# 22     CUST023  Female   35
# 23     CUST024  Female   49
# 24     CUST025  Female   64
# 25     CUST026  Female   28
# 26     CUST027  Female   38
# 27     CUST028  Female   43
# 28     CUST029  Female   42
# 29     CUST030  Female   39
# 30     CUST031    Male   44
# 31     CUST032    Male   30
# 32     CUST033  Female   50
# 33     CUST034  Female   51
# 34     CUST035  Female   58
# 35     CUST036    Male   52
# 36     CUST037  Female   18
# 37     CUST038    Male   38
# 38     CUST039    Male   23
# 39     CUST040    Male   45
# 40     CUST041    Male   34
# 41     CUST042    Male   22
# 42     CUST043  Female   48
# 43     CUST044  Female   22
# 44     CUST045  Female   55
# 45     CUST046  Female   20
# 46     CUST047  Female   40
# 47     CUST048    Male   54
# 48     CUST049  Female   54
# 49     CUST050  Female   27

# %% [markdown]
# ### 3. Remove Customer Demographics from Main Data
#
# We drop the `Customer ID`, `Gender`, and `Age` columns from the main dataset (df) to avoid redundancy after enriching the data.

# %%
df.drop(columns=['Customer ID','Gender','Age'],inplace=True)
df
# Out:
#      Transaction ID        Date Product Category  Quantity  Price per Unit  \
# 0                 1  2023-11-24           Beauty         3              50
# 1                 2  2023-02-27         Clothing         2             500
# 2                 3  2023-01-13      Electronics         1              30
# 3                 4  2023-05-21         Clothing         1             500
# 4                 5  2023-05-06           Beauty         2              50
# ..              ...         ...              ...       ...             ...
# 995             996  2023-05-16         Clothing         1              50
# 996             997  2023-11-17           Beauty         3              30
# 997             998  2023-10-29           Beauty         4              25
# 998             999  2023-12-05      Electronics         3              50
# 999            1000  2023-04-12      Electronics         4              30
#
#      Total Amount
# 0             150
# 1            1000
# 2              30
# 3             500
# 4             100
# ..            ...
# 995            50
# 996            90
# 997           100
# 998           150
# 999           120
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### 4. Create Province-City Mapping for generating geo-data
#
# A dictionary (`province_city_dict`) is created to map Canadian provinces to their respective cities. This will be used later to assign random cities and provinces to customers.

# %%
province_city_dict = {
    'Alberta': ['Calgary', 'Edmonton', 'Red Deer', 'Lethbridge'],
    'British Columbia': ['Vancouver', 'Victoria', 'Surrey', 'Burnaby'],
    'Manitoba': ['Winnipeg', 'Brandon', 'Steinbach', 'Thompson'],
    'New Brunswick': ['Fredericton', 'Moncton', 'Saint John'],
    'Newfoundland and Labrador': ['St. John\'s', 'Mount Pearl', 'Corner Brook'],
    'Nova Scotia': ['Halifax', 'Sydney', 'Dartmouth'],
    'Ontario': ['Toronto', 'Ottawa', 'Hamilton', 'Kitchener'],
    'Prince Edward Island': ['Charlottetown', 'Summerside'],
    'Quebec': ['Montreal', 'Quebec City', 'Laval', 'Gatineau'],
    'Saskatchewan': ['Saskatoon', 'Regina', 'Moose Jaw']
}

province_city_dict
# Out:
# {'Alberta': ['Calgary', 'Edmonton', 'Red Deer', 'Lethbridge'],
#  'British Columbia': ['Vancouver', 'Victoria', 'Surrey', 'Burnaby'],
#  'Manitoba': ['Winnipeg', 'Brandon', 'Steinbach', 'Thompson'],
#  'New Brunswick': ['Fredericton', 'Moncton', 'Saint John'],
#  'Newfoundland and Labrador': ["St. John's", 'Mount Pearl', 'Corner Brook'],
#  'Nova Scotia': ['Halifax', 'Sydney', 'Dartmouth'],
#  'Ontario': ['Toronto', 'Ottawa', 'Hamilton', 'Kitchener'],
#  'Prince Edward Island': ['Charlottetown', 'Summerside'],
#  'Quebec': ['Montreal', 'Quebec City', 'Laval', 'Gatineau'],
#  'Saskatchewan': ['Saskatoon', 'Regina', 'Moose Jaw']}

# %% [markdown]
# ### 5. Assign Random City and Province to Customers
#
# Using the `province_city_dict`, we randomly assign a province and a city to each customer. Additionally, a `Country` column is added with a default value of `Canada`. This information is then added to `customers_df`.

# %%
import numpy as np
np.random.seed(42)

# Function to assign random city and province
def assign_city_and_province():
    province = np.random.choice(list(province_city_dict.keys()))  # Randomly pick a province
    city = np.random.choice(province_city_dict[province])  # Randomly pick a city from the selected province
    return province, city

# Apply the function to add 'Province' and 'City' columns to the DataFrame

for index, row in customers_df.iterrows():
    province, city = assign_city_and_province()
    customers_df.at[index, 'City'] = city
    customers_df.at[index, 'Province'] = province
   

# Add 'Country' column with all values set to 'Canada'
customers_df['Country'] = 'Canada'
customers_df
# Out:
#    Customer ID  Gender  Age           City                   Province Country
# 0      CUST001    Male   34      Kitchener                    Ontario  Canada
# 1      CUST002  Female   26  Charlottetown       Prince Edward Island  Canada
# 2      CUST003    Male   50   Corner Brook  Newfoundland and Labrador  Canada
# 3      CUST004    Male   37      Moose Jaw               Saskatchewan  Canada
# 4      CUST005    Male   30       Hamilton                    Ontario  Canada
# 5      CUST006  Female   45  Charlottetown       Prince Edward Island  Canada
# 6      CUST007    Male   46     Saint John              New Brunswick  Canada
# 7      CUST008    Male   30        Halifax                Nova Scotia  Canada
# 8      CUST009    Male   63        Burnaby           British Columbia  Canada
# 9      CUST010  Female   52         Sydney                Nova Scotia  Canada
# 10     CUST011    Male   23     St. John's  Newfoundland and Labrador  Canada
# 11     CUST012    Male   35         Regina               Saskatchewan  Canada
# 12     CUST013    Male   22       Montreal                     Quebec  Canada
# 13     CUST014    Male   64      Moose Jaw               Saskatchewan  Canada
# 14     CUST015  Female   42       Thompson                   Manitoba  Canada
# 15     CUST016    Male   19      Kitchener                    Ontario  Canada
# 16     CUST017  Female   27          Laval                     Quebec  Canada
# 17     CUST018  Female   47   Corner Brook  Newfoundland and Labrador  Canada
# 18     CUST019  Female   62        Toronto                    Ontario  Canada
# 19     CUST020    Male   22          Laval                     Quebec  Canada
# 20     CUST021  Female   50        Burnaby           British Columbia  Canada
# 21     CUST022    Male   18       Gatineau                     Quebec  Canada
# 22     CUST023  Female   35       Victoria           British Columbia  Canada
# 23     CUST024  Female   49    Quebec City                     Quebec  Canada
# 24     CUST025  Female   64    Mount Pearl  Newfoundland and Labrador  Canada
# 25     CUST026  Female   28     Saint John              New Brunswick  Canada
# 26     CUST027  Female   38      Kitchener                    Ontario  Canada
# 27     CUST028  Female   43  Charlottetown       Prince Edward Island  Canada
# 28     CUST029  Female   42        Brandon                   Manitoba  Canada
# 29     CUST030  Female   39     Lethbridge                    Alberta  Canada
# 30     CUST031    Male   44        Burnaby           British Columbia  Canada
# 31     CUST032    Male   30        Moncton              New Brunswick  Canada
# 32     CUST033  Female   50         Sydney                Nova Scotia  Canada
# 33     CUST034  Female   51         Regina               Saskatchewan  Canada
# 34     CUST035  Female   58       Victoria           British Columbia  Canada
# 35     CUST036    Male   52       Victoria           British Columbia  Canada
# 36     CUST037  Female   18        Moncton              New Brunswick  Canada
# 37     CUST038    Male   38     Summerside       Prince Edward Island  Canada
# 38     CUST039    Male   23      Kitchener                    Ontario  Canada
# 39     CUST040    Male   45    Quebec City                     Quebec  Canada
# 40     CUST041    Male   34  Charlottetown       Prince Edward Island  Canada
# 41     CUST042    Male   22         Surrey           British Columbia  Canada
# 42     CUST043  Female   48    Mount Pearl  Newfoundland and Labrador  Canada
# 43     CUST044  Female   22       Gatineau                     Quebec  Canada
# 44     CUST045  Female   55       Montreal                     Quebec  Canada
# 45     CUST046  Female   20        Calgary                    Alberta  Canada
# 46     CUST047  Female   40        Toronto                    Ontario  Canada
# 47     CUST048    Male   54  Charlottetown       Prince Edward Island  Canada
# 48     CUST049  Female   54     Summerside       Prince Edward Island  Canada
# 49     CUST050  Female   27       Winnipeg                   Manitoba  Canada

# %% [markdown]
# ### 6. Merge Customer Demographics with Main Data
#
# We randomly assign a `Customer ID` from the `customers_df` to each row in the main dataset (`df`). The customer demographics are then merged with the main dataset based on the `Customer ID`.

# %%
# Randomly assign 'Customer ID' from customers_df to df
df['Customer ID'] = np.random.choice(customers_df['Customer ID'], size=len(df))

# Merge customer demographics into df
df = df.merge(customers_df[['Customer ID', 'Gender', 'Age', 'City', 'Province', 'Country']], on='Customer ID', how='left')

df
# Out:
#      Transaction ID        Date Product Category  Quantity  Price per Unit  \
# 0                 1  2023-11-24           Beauty         3              50
# 1                 2  2023-02-27         Clothing         2             500
# 2                 3  2023-01-13      Electronics         1              30
# 3                 4  2023-05-21         Clothing         1             500
# 4                 5  2023-05-06           Beauty         2              50
# ..              ...         ...              ...       ...             ...
# 995             996  2023-05-16         Clothing         1              50
# 996             997  2023-11-17           Beauty         3              30
# 997             998  2023-10-29           Beauty         4              25
# 998             999  2023-12-05      Electronics         3              50
# 999            1000  2023-04-12      Electronics         4              30
#
#      Total Amount Customer ID  Gender  Age        City          Province  \
# 0             150     CUST008    Male   30     Halifax       Nova Scotia
# 1            1000     CUST035  Female   58    Victoria  British Columbia
# 2              30     CUST035  Female   58    Victoria  British Columbia
# 3             500     CUST033  Female   50      Sydney       Nova Scotia
# 4             100     CUST005    Male   30    Hamilton           Ontario
# ..            ...         ...     ...  ...         ...               ...
# 995            50     CUST014    Male   64   Moose Jaw      Saskatchewan
# 996            90     CUST030  Female   39  Lethbridge           Alberta
# 997           100     CUST035  Female   58    Victoria  British Columbia
# 998           150     CUST021  Female   50     Burnaby  British Columbia
# 999           120     CUST037  Female   18     Moncton     New Brunswick
#
#     Country
# 0    Canada
# 1    Canada
# 2    Canada
# 3    Canada
# 4    Canada
# ..      ...
# 995  Canada
# 996  Canada
# 997  Canada
# 998  Canada
# 999  Canada
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### 7. Add Season Information Based on Date
# We convert the `Date` column to a datetime format and then create a new column `Season` to categorize transactions into one of four seasons (Spring, Summer, Fall, Winter) based on the date.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Define a function to determine the season based on the date
def get_season(date):
    # Get the month and day from the date
    month_day = date.month * 100 + date.day  # Convert month and day into a number (e.g., March 21 -> 321)

    # Determine season based on the month and day
    if 321 <= month_day <= 620:
        return 'Spring'
    elif 621 <= month_day <= 922:
        return 'Summer'
    elif 923 <= month_day <= 1220:
        return 'Fall'
    else:  # Covers both Winter cases (Dec 21 - Dec 31 and Jan 1 - Mar 20)
        return 'Winter'

# Apply the function to create the 'Season' column
df['Season'] = df['Date'].apply(get_season)

df
# Out:
#      Transaction ID       Date Product Category  Quantity  Price per Unit  \
# 0                 1 2023-11-24           Beauty         3              50
# 1                 2 2023-02-27         Clothing         2             500
# 2                 3 2023-01-13      Electronics         1              30
# 3                 4 2023-05-21         Clothing         1             500
# 4                 5 2023-05-06           Beauty         2              50
# ..              ...        ...              ...       ...             ...
# 995             996 2023-05-16         Clothing         1              50
# 996             997 2023-11-17           Beauty         3              30
# 997             998 2023-10-29           Beauty         4              25
# 998             999 2023-12-05      Electronics         3              50
# 999            1000 2023-04-12      Electronics         4              30
#
#      Total Amount Customer ID  Gender  Age        City          Province  \
# 0             150     CUST008    Male   30     Halifax       Nova Scotia
# 1            1000     CUST035  Female   58    Victoria  British Columbia
# 2              30     CUST035  Female   58    Victoria  British Columbia
# 3             500     CUST033  Female   50      Sydney       Nova Scotia
# 4             100     CUST005    Male   30    Hamilton           Ontario
# ..            ...         ...     ...  ...         ...               ...
# 995            50     CUST014    Male   64   Moose Jaw      Saskatchewan
# 996            90     CUST030  Female   39  Lethbridge           Alberta
# 997           100     CUST035  Female   58    Victoria  British Columbia
# 998           150     CUST021  Female   50     Burnaby  British Columbia
# 999           120     CUST037  Female   18     Moncton     New Brunswick
#
#     Country  Season
# 0    Canada    Fall
# 1    Canada  Winter
# 2    Canada  Winter
# 3    Canada  Spring
# 4    Canada  Spring
# ..      ...     ...
# 995  Canada  Spring
# 996  Canada    Fall
# 997  Canada    Fall
# 998  Canada    Fall
# 999  Canada  Spring
#
# [1000 rows x 13 columns]

# %% [markdown]
# ### 8. Assign Random Discount Flag
#
# A random `True` or `False` value is assigned to the `is_discount` column, representing whether a transaction had a discount.

# %%
df['is_discount'] = np.random.choice([True, False], size=len(df))
df
# Out:
#      Transaction ID       Date Product Category  Quantity  Price per Unit  \
# 0                 1 2023-11-24           Beauty         3              50
# 1                 2 2023-02-27         Clothing         2             500
# 2                 3 2023-01-13      Electronics         1              30
# 3                 4 2023-05-21         Clothing         1             500
# 4                 5 2023-05-06           Beauty         2              50
# ..              ...        ...              ...       ...             ...
# 995             996 2023-05-16         Clothing         1              50
# 996             997 2023-11-17           Beauty         3              30
# 997             998 2023-10-29           Beauty         4              25
# 998             999 2023-12-05      Electronics         3              50
# 999            1000 2023-04-12      Electronics         4              30
#
#      Total Amount Customer ID  Gender  Age        City          Province  \
# 0             150     CUST008    Male   30     Halifax       Nova Scotia
# 1            1000     CUST035  Female   58    Victoria  British Columbia
# 2              30     CUST035  Female   58    Victoria  British Columbia
# 3             500     CUST033  Female   50      Sydney       Nova Scotia
# 4             100     CUST005    Male   30    Hamilton           Ontario
# ..            ...         ...     ...  ...         ...               ...
# 995            50     CUST014    Male   64   Moose Jaw      Saskatchewan
# 996            90     CUST030  Female   39  Lethbridge           Alberta
# 997           100     CUST035  Female   58    Victoria  British Columbia
# 998           150     CUST021  Female   50     Burnaby  British Columbia
# 999           120     CUST037  Female   18     Moncton     New Brunswick
#
#     Country  Season  is_discount
# 0    Canada    Fall         True
# 1    Canada  Winter         True
# 2    Canada  Winter         True
# 3    Canada  Spring        False
# 4    Canada  Spring        False
# ..      ...     ...          ...
# 995  Canada  Spring         True
# 996  Canada    Fall         True
# 997  Canada    Fall        False
# 998  Canada    Fall        False
# 999  Canada  Spring        False
#
# [1000 rows x 14 columns]

# %% [markdown]
# ### 9. Sort Data by Date
#
# The dataset is sorted in ascending order by the `Date` column to ensure that the transactions are `ordered chronologically`.

# %%
df = df.sort_values(by='Date', ascending=True)
df
# Out:
#      Transaction ID       Date Product Category  Quantity  Price per Unit  \
# 521             522 2023-01-01           Beauty         3             500
# 179             180 2023-01-01         Clothing         3             300
# 558             559 2023-01-01         Clothing         4             300
# 302             303 2023-01-02      Electronics         3              30
# 978             979 2023-01-02           Beauty         1              25
# ..              ...        ...              ...       ...             ...
# 232             233 2023-12-29           Beauty         2             300
# 804             805 2023-12-29           Beauty         3             500
# 856             857 2023-12-31      Electronics         2              25
# 210             211 2024-01-01           Beauty         3             500
# 649             650 2024-01-01      Electronics         1              30
#
#      Total Amount Customer ID  Gender  Age           City  \
# 521          1500     CUST045  Female   55       Montreal
# 179           900     CUST041    Male   34  Charlottetown
# 558          1200     CUST022    Male   18       Gatineau
# 302            90     CUST007    Male   46     Saint John
# 978            25     CUST044  Female   22       Gatineau
# ..            ...         ...     ...  ...            ...
# 232           600     CUST027  Female   38      Kitchener
# 804          1500     CUST046  Female   20        Calgary
# 856            50     CUST017  Female   27          Laval
# 210          1500     CUST033  Female   50         Sydney
# 649            30     CUST013    Male   22       Montreal
#
#                  Province Country  Season  is_discount
# 521                Quebec  Canada  Winter         True
# 179  Prince Edward Island  Canada  Winter         True
# 558                Quebec  Canada  Winter         True
# 302         New Brunswick  Canada  Winter         True
# 978                Quebec  Canada  Winter         True
# ..                    ...     ...     ...          ...
# 232               Ontario  Canada  Winter         True
# 804               Alberta  Canada  Winter        False
# 856                Quebec  Canada  Winter         True
# 210           Nova Scotia  Canada  Winter        False
# 649                Quebec  Canada  Winter         True
#
# [1000 rows x 14 columns]

# %% [markdown]
# ### 10. Assign Transaction IDs
#
# A `Transaction` ID is assigned sequentially to each transaction, starting from 1.

# %%
df['Transaction ID'] = range(1, len(df) + 1)
df
# Out:
#      Transaction ID       Date Product Category  Quantity  Price per Unit  \
# 521               1 2023-01-01           Beauty         3             500
# 179               2 2023-01-01         Clothing         3             300
# 558               3 2023-01-01         Clothing         4             300
# 302               4 2023-01-02      Electronics         3              30
# 978               5 2023-01-02           Beauty         1              25
# ..              ...        ...              ...       ...             ...
# 232             996 2023-12-29           Beauty         2             300
# 804             997 2023-12-29           Beauty         3             500
# 856             998 2023-12-31      Electronics         2              25
# 210             999 2024-01-01           Beauty         3             500
# 649            1000 2024-01-01      Electronics         1              30
#
#      Total Amount Customer ID  Gender  Age           City  \
# 521          1500     CUST045  Female   55       Montreal
# 179           900     CUST041    Male   34  Charlottetown
# 558          1200     CUST022    Male   18       Gatineau
# 302            90     CUST007    Male   46     Saint John
# 978            25     CUST044  Female   22       Gatineau
# ..            ...         ...     ...  ...            ...
# 232           600     CUST027  Female   38      Kitchener
# 804          1500     CUST046  Female   20        Calgary
# 856            50     CUST017  Female   27          Laval
# 210          1500     CUST033  Female   50         Sydney
# 649            30     CUST013    Male   22       Montreal
#
#                  Province Country  Season  is_discount
# 521                Quebec  Canada  Winter         True
# 179  Prince Edward Island  Canada  Winter         True
# 558                Quebec  Canada  Winter         True
# 302         New Brunswick  Canada  Winter         True
# 978                Quebec  Canada  Winter         True
# ..                    ...     ...     ...          ...
# 232               Ontario  Canada  Winter         True
# 804               Alberta  Canada  Winter        False
# 856                Quebec  Canada  Winter         True
# 210           Nova Scotia  Canada  Winter        False
# 649                Quebec  Canada  Winter         True
#
# [1000 rows x 14 columns]

# %% [markdown]
# ### 11. Label Customers as 'New' or 'Returning'
#
# A `Customer Type` column is added, labeling customers as either 'New' or 'Returning' based on whether they have made a prior transaction.

# %%
new_customers = set()

# Function to label customers as 'New' or 'Returning' in a cumulative manner
def get_customer_type(row):
    if row['Customer ID'] not in new_customers:
        new_customers.add(row['Customer ID'])
        return 'New'
    else:
        return 'Returning'

# Apply the function to the DataFrame to create the 'Customer Type' column
df['Customer Type'] = df.apply(get_customer_type, axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 521 to 649
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Product Category  1000 non-null   object
#  3   Quantity          1000 non-null   int64
#  4   Price per Unit    1000 non-null   int64
#  5   Total Amount      1000 non-null   int64
#  6   Customer ID       1000 non-null   object
#  7   Gender            1000 non-null   object
#  8   Age               1000 non-null   int64
#  9   City              1000 non-null   object
#  10  Province          1000 non-null   object
#  11  Country           1000 non-null   object
#  12  Season            1000 non-null   object
#  13  is_discount       1000 non-null   bool
#  14  Customer Type     1000 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(5), object(8)
# memory usage: 118.2+ KB

# %% [markdown]
# ### 12. Calculate Total Spend per Customer
#
# The total amount spent by each customer (`Total Spend`) is calculated and added to the dataset.

# %%
total_spend = df.groupby('Customer ID')['Total Amount'].sum().reset_index()

# Rename the 'Total Amount' column to 'Total Spend'
total_spend.rename(columns={'Total Amount': 'Total Spend'}, inplace=True)

# Merge the total spend back into the original dataframe
df = df.merge(total_spend, on='Customer ID', how='left')

print(df[['Customer ID', 'Total Spend']].head())
df
# Out:
#   Customer ID  Total Spend
# 0     CUST045        10525
# 1     CUST041         7650
# 2     CUST022        11785
# 3     CUST007         4910
# 4     CUST044         8150
#      Transaction ID       Date Product Category  Quantity  Price per Unit  \
# 0                 1 2023-01-01           Beauty         3             500
# 1                 2 2023-01-01         Clothing         3             300
# 2                 3 2023-01-01         Clothing         4             300
# 3                 4 2023-01-02      Electronics         3              30
# 4                 5 2023-01-02           Beauty         1              25
# ..              ...        ...              ...       ...             ...
# 995             996 2023-12-29           Beauty         2             300
# 996             997 2023-12-29           Beauty         3             500
# 997             998 2023-12-31      Electronics         2              25
# 998             999 2024-01-01           Beauty         3             500
# 999            1000 2024-01-01      Electronics         1              30
#
#      Total Amount Customer ID  Gender  Age           City  \
# 0            1500     CUST045  Female   55       Montreal
# 1             900     CUST041    Male   34  Charlottetown
# 2            1200     CUST022    Male   18       Gatineau
# 3              90     CUST007    Male   46     Saint John
# 4              25     CUST044  Female   22       Gatineau
# ..            ...         ...     ...  ...            ...
# 995           600     CUST027  Female   38      Kitchener
# 996          1500     CUST046  Female   20        Calgary
# 997            50     CUST017  Female   27          Laval
# 998          1500     CUST033  Female   50         Sydney
# 999            30     CUST013    Male   22       Montreal
#
#                  Province Country  Season  is_discount Customer Type  \
# 0                  Quebec  Canada  Winter         True           New
# 1    Prince Edward Island  Canada  Winter         True           New
# 2                  Quebec  Canada  Winter         True           New
# 3           New Brunswick  Canada  Winter         True           New
# 4                  Quebec  Canada  Winter         True           New
# ..                    ...     ...     ...          ...           ...
# 995               Ontario  Canada  Winter         True     Returning
# 996               Alberta  Canada  Winter        False     Returning
# 997                Quebec  Canada  Winter         True     Returning
# 998           Nova Scotia  Canada  Winter        False     Returning
# 999                Quebec  Canada  Winter         True     Returning
#
#      Total Spend
# 0          10525
# 1           7650
# 2          11785
# 3           4910
# 4           8150
# ..           ...
# 995         4250
# 996         4380
# 997         9755
# 998        20180
# 999         5740
#
# [1000 rows x 16 columns]

# %% [markdown]
# ### 13. Assign Product ID
#
# A unique Product ID is generated for each combination of `Product Category` and `Price per Unit`.

# %%
df['Product ID'] = df.groupby(['Product Category', 'Price per Unit']).ngroup() + 1

print(df[['Transaction ID', 'Product Category', 'Price per Unit', 'Product ID']])
# Out:
#      Transaction ID Product Category  Price per Unit  Product ID
# 0                 1           Beauty             500           5
# 1                 2         Clothing             300           9
# 2                 3         Clothing             300           9
# 3                 4      Electronics              30          12
# 4                 5           Beauty              25           1
# ..              ...              ...             ...         ...
# 995             996           Beauty             300           4
# 996             997           Beauty             500           5
# 997             998      Electronics              25          11
# 998             999           Beauty             500           5
# 999            1000      Electronics              30          12
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### 14. Save Processed Data
#
# Finally, the transformed dataset is saved to a new CSV file (`retail_sales_dataset.csv`) for further analysis or reporting.

# %%
df.to_csv('./processed/retail_sales_dataset.csv', index=False)

# %% [markdown]
# ### Optional verifications

# %% [markdown]
# - Total number of unique customers in the dataset.

# %%
customer_transactions = df.groupby('Customer ID').size()
customer_transactions
# Out:
# Customer ID
# CUST001    25
# CUST002    21
# CUST003    22
# CUST004    16
# CUST005    26
# CUST006    22
# CUST007    11
# CUST008    20
# CUST009    18
# CUST010    17
# CUST011    20
# CUST012    22
# CUST013    19
# CUST014    17
# CUST015    15
# CUST016    19
# CUST017    21
# CUST018    13
# CUST019    19
# CUST020    18
# CUST021    16
# CUST022    21
# CUST023    22
# CUST024    20
# CUST025    20
# CUST026    30
# CUST027    15
# CUST028    28
# CUST029    17
# CUST030    22
# CUST031    16
# CUST032    25
# CUST033    29
# CUST034    18
# CUST035    31
# CUST036    20
# CUST037    29
# CUST038    16
# CUST039    22
# CUST040    16
# CUST041    18
# CUST042    15
# CUST043    11
# CUST044    18
# CUST045    22
# CUST046    13
# CUST047    23
# CUST048    21
# CUST049    29
# CUST050    16
# dtype: int64

# %% [markdown]
# - Distinct Product IDs Count

# %%
distinct_product_ids = df['Product ID'].drop_duplicates()
distinct_product_ids.size
# Out:
# 15
